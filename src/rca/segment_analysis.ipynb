# %% [markdown]
# # Segment Contribution Analysis
#
#
# ## Load data
#
# 1. Aggregate transaction-level data.
# To make the analysis more meaningful, I introduced controlled perturbations to simulate noticeable growth patterns.
#
# 2. Select a target merchant and benchmark key business metrics (e.g., transaction amount, transaction count) against peer merchants within the same category.

# %%
import pandas as pd
import numpy as np
import etl
from segment_analysis import exhaustive_eval

# %%
TARGET_MERCHANTS = "fraud_Kilback LLC"
target_col = "amt_growth_ctc_diff"

df_combined = etl.load_rca_data(TARGET_MERCHANTS)
# Out:
# File exists, loading data from /Users/yanxinye/github/competency-intelligence/src/rca/etl/rca_fraud_Kilback LLC.csv...

# %% [markdown]
# ## Segment-Level Decomposition
#
# ### Option1: Exhaustive evaluation of dimension interactions
#
# An intuitive approach to identifying segments that explain the gap between a target merchant and its peers is to compute metrics across all combinations of dimension columns (i.e., k-way interactions).
#
# This results in **O(2ⁿ)** complexity, with computational cost growing exponentially as the number of dimensions increases.
#
# To maintain tractability, we can cap the interaction depth (e.g., *k ≤ 3*), trading off computational efficiency against the ability to capture higher-order interactions.

# %%
sorted_res = exhaustive_eval(df_combined, target_col)

total = df_combined[target_col].sum()
print(f"The total growth difference is: {total:.2%}")
print("Top segment drivers:\n")
for i, (k, v) in enumerate(sorted_res[:20], 1):
    print(f"{i:>2}. {k:<50} | {v:>8.2%} | contribution: {v/total:>6.2%}")
# Out:
# The total growth difference is: 25.87%
# Top segment drivers:
#
#  1. gender = F                                         |   18.82% | contribution: 72.73%
#  2. generation = Gen X                                 |   14.10% | contribution: 54.49%
#  3. category = food_dining                             |   13.58% | contribution: 52.49%
#  4. category = grocery_pos                             |   12.29% | contribution: 47.51%
#  5. generation = Millennial                            |   11.14% | contribution: 43.07%
#  6. gender = F, category = grocery_pos                 |    9.56% | contribution: 36.96%
#  7. gender = F, category = food_dining                 |    9.25% | contribution: 35.77%
#  8. generation = Gen X, category = grocery_pos         |    8.70% | contribution: 33.65%
#  9. generation = Gen X, state = CA                     |    8.39% | contribution: 32.43%
# 10. state = CA                                         |    7.94% | contribution: 30.69%
# 11. generation = Millennial, gender = F                |    7.91% | contribution: 30.58%
# 12. generation = Gen X, gender = F                     |    7.88% | contribution: 30.44%
# 13. generation = Gen X, state = NY                     |    7.70% | contribution: 29.77%
# 14. generation = Gen X, state = NY, category = grocery_pos |    7.25% | contribution: 28.03%
# 15. gender = M                                         |    7.06% | contribution: 27.27%
# 16. generation = Millennial, category = grocery_pos    |    6.60% | contribution: 25.52%
# 17. generation = Gen X, state = CA, category = grocery_pos |    6.57% | contribution: 25.40%
# 18. generation = Gen X, gender = M                     |    6.22% | contribution: 24.05%
# 19. generation = Gen X, state = CA, gender = F         |    6.08% | contribution: 23.50%
# 20. generation = Millennial, gender = F, category = grocery_pos |    6.00% | contribution: 23.19%
